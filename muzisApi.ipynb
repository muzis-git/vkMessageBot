# %%
import requests
import json

# %% [markdown]
# #Muzis api

# %%
muzis = 'http://muzis.ru/api'
q_track = 'люблю'
data={'q_track': q_track}
resp = requests.post(muzis+'/search.api', data=(data))
# resp = requests.post(muzis+'/search.api','q_track={}'.format(q_track))
result = resp.content
print result
print (json.dumps(result, indent=4, sort_keys=True, ensure_ascii=False))
# Out:
# {"songs": [{"values_all": [1104, 23509, 32453, 25, 17], "performer": "\u0425\u0430\u043a\u0438", "lyrics": "\u0418 \u0432\u0441\u0435-\u0442\u0430\u043a\u0438 \u043b\u044e\u0431\u043b\u044e...\r\n\u041c\u0443\u0437. \u0414\u043c\u0438\u0442\u0440\u0438\u0439 \u041c\u043e\u0441\u0441,\r\n\u0441\u043b.\u041b\u044e\u0431\u043e\u0432\u044c \u041b\u0435\u0440\u043e\u043a\u0441\r\n\u0422\u044b \u043d\u0438\u043a\u043e\u0433\u0434\u0430 \u0443\u0436\u0435 \u043d\u0435 \u043f\u0440\u0438\u0434\u0451\u0448\u044c,\r\n\u043d\u0435 \u043f\u043e\u043c\u043e\u043b\u0447\u0438\u0448\u044c \u0441\u043e \u043c\u043d\u043e\u0439.\r\n\u0422\u0430\u043a \u0434\u043b\u044f \u0447\u0435\u0433\u043e \u0436\u0435 \u0442\u0435\u043f\u0435\u0440\u044c \u043c\u043d\u0435 \u043e\u043d\u0438 \u043a\u0440\u044b\u043b\u044c\u044f \u0437\u0430 \u0441\u043f\u0438\u043d\u043e\u0439?\r\n\u041c\u043d\u0435 \u043d\u0430\u0432\u0441\u0435\u0433\u0434\u0430 \u043e\u0441\u0442\u0430\u043d\u0435\u0442\u0441\u044f \u0431\u04
# ...
